# %% [markdown]
# <a href="https://colab.research.google.com/github/mariaangelesferrero/Dataset---Ferrero/blob/main/Copia_de_Ferrero_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = 'https://github.com/mariaangelesferrero/Dataset---Ferrero/blob/main/climate_change_impact_on_agriculture_2024.csv'
df = pd.read_csv('url')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-4d4dd132736e> in <cell line: 2>()
#       1 url = 'https://github.com/mariaangelesferrero/Dataset---Ferrero/blob/main/climate_change_impact_on_agriculture_2024.csv'
# ----> 2 df = pd.read_csv('url')
#       3 df.head()
#
# ...

# %%
url = 'climate_change_impact_on_agriculture_2024.csv'
df = pd.read_csv('url')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-2fa9b21b38e7> in <cell line: 2>()
#       1 url = 'climate_change_impact_on_agriculture_2024.csv'
# ----> 2 df = pd.read_csv('url')
#       3 df.head()
#
# ...

# %%
url = 'https://raw.githubusercontent.com/mariaangelesferrero/Dataset---Ferrero/refs/heads/main/climate_change_impact_on_agriculture_2024.csv'

# %%
df = pd.read_csv(url)
df.head()
# Out:
#    Year Country         Region  Crop_Type  Average_Temperature_C  \
# 0  2001   India    West Bengal       Corn                   1.55
# 1  2024   China          North       Corn                   3.23
# 2  2001  France  Ile-de-France      Wheat                  21.11
# 3  2001  Canada       Prairies     Coffee                  27.85
# 4  1998   India     Tamil Nadu  Sugarcane                   2.19
#
#    Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 0                  447.06             15.22                 1.737
# 1                 2913.57             29.82                 1.737
# 2                 1301.74             25.75                 1.719
# 3                 1154.36             13.91                 3.890
# 4                 1627.48             11.81                 1.080
#
#    Extreme_Weather_Events  Irrigation_Access_%  Pesticide_Use_KG_per_HA  \
# 0                       8                14.54                    10.08
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         10000 non-null  int64
#  1   Country                      10000 non-null  object
#  2   Region                       10000 non-null  object
#  3   Crop_Type                    10000 non-null  object
#  4   Average_Temperature_C        10000 non-null  float64
#  5   Total_Precipitation_mm       10000 non-null  float64
#  6   CO2_Emissions_MT             10000 non-null  float64
#  7   Crop_Yield_MT_per_HA         10000 non-null  float64
#  8   Extreme_Weather_Events       10000 non-null  int64
#  9   Irrigation_Access_%          10000 non-null  float64
#  10  Pesticide_Use_KG_per_HA      10000 non-null  float64
#  11  Fertilizer_Use_KG_per_HA     10000 non-null  float64
# ...

# %%
df.describe()
# Out:
#                Year  Average_Temperature_C  Total_Precipitation_mm  \
# count  10000.000000           10000.000000            10000.000000
# mean    2007.088700              15.241299             1611.663834
# std       10.084245              11.466955              805.016815
# min     1990.000000              -4.990000              200.150000
# 25%     1999.000000               5.430000              925.697500
# 50%     2007.000000              15.175000             1611.160000
# 75%     2016.000000              25.340000             2306.997500
# max     2024.000000              35.000000             2999.670000
#
#        CO2_Emissions_MT  Crop_Yield_MT_per_HA  Extreme_Weather_Events  \
# count      10000.000000          10000.000000            10000.000000
# mean          15.246608              2.240017                4.980900
# std            8.589423              0.998342                3.165808
# min            0.500000              0.450000                0.000000
# ...

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-2f6f6606aa2c> in <cell line: 1>()
# ----> 1 df.corr()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994         if result.dtype is not dtype:
#    1995             result = np.asarray(result, dtype=dtype)
#
# ...
